# %% [markdown]
# # Improving far object Detection

# %% [markdown]
# ## working fine

# %%
# create and activate python virtual environment

# %%
#run this once 
! pip install -r requirments.txt
# Out:
# Requirement already satisfied: numpy in ./venv/lib/python3.10/site-packages (from -r requirments.txt (line 1)) (1.26.4)
# Requirement already satisfied: opencv-python in ./venv/lib/python3.10/site-packages (from -r requirments.txt (line 2)) (4.10.0.84)
# Requirement already satisfied: keras in ./venv/lib/python3.10/site-packages (from -r requirments.txt (line 3)) (3.6.0)
# Requirement already satisfied: tensorflow in ./venv/lib/python3.10/site-packages (from -r requirments.txt (line 4)) (2.16.2)
# Requirement already satisfied: ultralytics in ./venv/lib/python3.10/site-packages (from -r requirments.txt (line 5)) (8.3.37)
# Requirement already satisfied: ipykernel in ./venv/lib/python3.10/site-packages (from -r requirments.txt (line 6)) (6.29.5)
# Requirement already satisfied: ml-dtypes in ./venv/lib/python3.10/site-packages (from keras->-r requirments.txt (line 3)) (0.3.2)
# Requirement already satisfied: rich in ./venv/lib/python3.10/site-packages (from keras->-r requirments.txt (line 3)) (13.9.4)
# Requirement already satisfied: namex in ./venv/lib/python3.10/site-packages (from keras->-r requirments.txt (line 3)) (0.0.8)
# Requirement already satisfied: absl-py in ./venv/lib/python3.10/site-packages (from keras->-r requirments.txt (line 3)) (2.1.0)
# Requirement already satisfied: optree in ./venv/lib/python3.10/site-packages (from keras->-r requirments.txt (line 3)) (0.13.1)
# Requirement already satisfied: packaging in ./venv/lib/python3.10/site-packages (from keras->-r requirments.txt (line 3)) (24.2)
# Requirement already satisfied: h5py in ./venv/lib/python3.10/site-packages (from keras->-r requirments.txt (line 3)) (3.12.1)
# Requirement already satisfied: astunparse>=1.6.0 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (2.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (1.68.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (1.17.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (0.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (4.12.2)
# Requirement already satisfied: requests<3,>=2.21.0 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (2.32.3)
# Requirement already satisfied: libclang>=13.0.0 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (3.4.0)
# Requirement already satisfied: six>=1.12.0 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (1.16.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (24.3.25)
# Requirement already satisfied: google-pasta>=0.1.1 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (0.2.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (58.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (0.37.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (2.16.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./venv/lib/python3.10/site-packages (from tensorflow->-r requirments.txt (line 4)) (4.25.5)
# Requirement already satisfied: torch>=1.8.0 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (2.2.2)
# Requirement already satisfied: psutil in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (6.1.0)
# Requirement already satisfied: matplotlib>=3.3.0 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (3.9.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (2.0.12)
# Requirement already satisfied: py-cpuinfo in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (9.0.0)
# Requirement already satisfied: torchvision>=0.9.0 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (0.17.2)
# Requirement already satisfied: seaborn>=0.11.0 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (0.13.2)
# Requirement already satisfied: pillow>=7.1.2 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (6.0.2)
# Requirement already satisfied: pandas>=1.1.4 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (2.2.3)
# Requirement already satisfied: scipy>=1.4.1 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (1.14.1)
# Requirement already satisfied: tqdm>=4.64.0 in ./venv/lib/python3.10/site-packages (from ultralytics->-r requirments.txt (line 5)) (4.67.1)
# Requirement already satisfied: pyzmq>=24 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (26.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (1.8.9)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (8.6.3)
# Requirement already satisfied: traitlets>=5.4.0 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (5.14.3)
# Requirement already satisfied: appnope in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (0.1.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (5.7.2)
# Requirement already satisfied: nest-asyncio in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (1.6.0)
# Requirement already satisfied: comm>=0.1.1 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (0.2.2)
# Requirement already satisfied: tornado>=6.1 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (6.4.2)
# Requirement already satisfied: ipython>=7.23.1 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (8.29.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./venv/lib/python3.10/site-packages (from ipykernel->-r requirments.txt (line 6)) (0.1.7)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow->-r requirments.txt (line 4)) (0.45.1)
# Requirement already satisfied: stack-data in ./venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (0.6.3)
# Requirement already satisfied: decorator in ./venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in ./venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in ./venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (2.18.0)
# Requirement already satisfied: exceptiongroup in ./venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirments.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirments.txt (line 6)) (4.3.6)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirments.txt (line 5)) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirments.txt (line 5)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirments.txt (line 5)) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirments.txt (line 5)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics->-r requirments.txt (line 5)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics->-r requirments.txt (line 5)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics->-r requirments.txt (line 5)) (2024.2)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (0.2.13)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirments.txt (line 4)) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirments.txt (line 4)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirments.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirments.txt (line 4)) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in ./venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r requirments.txt (line 4)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r requirments.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./venv/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r requirments.txt (line 4)) (3.1.3)
# Requirement already satisfied: filelock in ./venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics->-r requirments.txt (line 5)) (3.16.1)
# Requirement already satisfied: fsspec in ./venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics->-r requirments.txt (line 5)) (2024.10.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics->-r requirments.txt (line 5)) (3.4.2)
# Requirement already satisfied: sympy in ./venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics->-r requirments.txt (line 5)) (1.13.3)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics->-r requirments.txt (line 5)) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow->-r requirments.txt (line 4)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.10/site-packages (from rich->keras->-r requirments.txt (line 3)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras->-r requirments.txt (line 3)) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (2.4.1)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirments.txt (line 6)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics->-r requirments.txt (line 5)) (1.3.0)
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the '/Users/kartiksharma/Traafic Signal Detection/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Load YOLO model
model = YOLO("./best.pt") # Replace with your trained model path

def detect_shapes_and_predict(frame):
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Edge detection
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours with hierarchy
    contours, hierarchy = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    for i, contour in enumerate(contours):
        # Filter only outermost contours
        if hierarchy[0][i][3] != -1:  # Check if contour has a parent
            continue

        # Ignore small contours
        area = cv2.contourArea(contour)
        if area < 500:  # Adjust this threshold to suit your application
            continue

        # Approximate the contour to a polygon
        epsilon = 0.04 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)

        # Identify shapes
        x, y, w, h = cv2.boundingRect(approx)
        shape = None
        if len(approx) == 3:
            shape = "Triangle"
        elif len(approx) == 4:
            shape = "Rectangle"
        elif len(approx) > 4:
            (cx, cy), radius = cv2.minEnclosingCircle(contour)
            if radius > 10:  # Filter small circles
                shape = "Circle"

        # If a shape is identified, predict with YOLO
        if shape:
            roi = frame[y:y+h, x:x+w]  # Crop the region of interest
            if roi.size > 0:  # Ensure ROI is not empty
                results = model.predict(roi, conf=0.8, imgsz=320)
                
                # Process YOLO predictions
                for result in results[0].boxes:
                    conf = result.conf.item()  # Confidence of the prediction
                    cls = result.cls.item()  # Class index
                    label = results[0].names[int(cls)]  # Class name

                    if conf > 0.8:  # Apply confidence threshold
                        # Draw the detected shape and classification
                        cv2.putText(frame, f"{shape}: {label} ({conf:.2f})", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    return frame

# Open video capture
cap = cv2.VideoCapture(0)  # 0 for default camera, replace with video path if needed

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Process the frame for shape and sign detection
    output_frame = detect_shapes_and_predict(frame)

    # Display the output
    cv2.imshow("Real-Time Shape and Sign Detection", output_frame)

    # Exit on 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x128 (no detections), 238.7ms
# Speed: 7.4ms preprocess, 238.7ms inference, 15.7ms postprocess per image at shape (1, 3, 320, 128)
#
# 0: 320x224 (no detections), 254.1ms
# Speed: 2.6ms preprocess, 254.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 288x320 (no detections), 211.8ms
# Speed: 2.2ms preprocess, 211.8ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 256x320 (no detections), 362.5ms
# Speed: 9.7ms preprocess, 362.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 160x320 (no detections), 175.2ms
# Speed: 12.7ms preprocess, 175.2ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 160x320 (no detections), 141.3ms
# Speed: 1.7ms preprocess, 141.3ms inference, 1.8ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 160x320 (no detections), 157.7ms
# Speed: 1.4ms preprocess, 157.7ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 177.3ms
# Speed: 1.8ms preprocess, 177.3ms inference, 3.1ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 178.4ms
# Speed: 6.9ms preprocess, 178.4ms inference, 3.2ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x256 (no detections), 201.5ms
# Speed: 1.5ms preprocess, 201.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 128x320 (no detections), 125.4ms
# Speed: 3.6ms preprocess, 125.4ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 256x320 (no detections), 191.2ms
# Speed: 2.0ms preprocess, 191.2ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 128x320 (no detections), 118.3ms
# Speed: 1.2ms preprocess, 118.3ms inference, 0.9ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 128x320 (no detections), 120.1ms
# Speed: 1.6ms preprocess, 120.1ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 192x320 (no detections), 194.5ms
# Speed: 2.0ms preprocess, 194.5ms inference, 0.8ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 160x320 (no detections), 206.6ms
# Speed: 12.6ms preprocess, 206.6ms inference, 0.7ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 262.4ms
# Speed: 13.5ms preprocess, 262.4ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 168.9ms
# Speed: 1.5ms preprocess, 168.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 185.1ms
# Speed: 2.8ms preprocess, 185.1ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 224x320 (no detections), 186.5ms
# Speed: 1.5ms preprocess, 186.5ms inference, 3.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 256x320 (no detections), 172.8ms
# Speed: 1.3ms preprocess, 172.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 192x320 (no detections), 157.9ms
# Speed: 1.1ms preprocess, 157.9ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 160x320 (no detections), 135.4ms
# Speed: 1.2ms preprocess, 135.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 177.4ms
# Speed: 3.3ms preprocess, 177.4ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 188.4ms
# Speed: 2.2ms preprocess, 188.4ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x288 (no detections), 207.9ms
# Speed: 2.0ms preprocess, 207.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 320x224 1 No_Vehicles, 169.8ms
# Speed: 1.4ms preprocess, 169.8ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 128x320 (no detections), 510.6ms
# Speed: 1.1ms preprocess, 510.6ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 256x320 (no detections), 192.7ms
# Speed: 2.1ms preprocess, 192.7ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x96 (no detections), 155.0ms
# Speed: 1.7ms preprocess, 155.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 320x256 (no detections), 213.5ms
# Speed: 35.1ms preprocess, 213.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 288x320 (no detections), 195.2ms
# Speed: 1.9ms preprocess, 195.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 320x288 1 Speed_Limit_20, 210.5ms
# Speed: 1.4ms preprocess, 210.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 256x320 (no detections), 186.6ms
# Speed: 5.7ms preprocess, 186.6ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x160 (no detections), 166.0ms
# Speed: 3.1ms preprocess, 166.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 160)
#
# 0: 320x288 1 Speed_Limit_20, 200.2ms
# Speed: 1.8ms preprocess, 200.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 320x96 (no detections), 136.3ms
# Speed: 2.3ms preprocess, 136.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 320x256 (no detections), 301.4ms
# Speed: 1.8ms preprocess, 301.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 160x320 (no detections), 134.9ms
# Speed: 0.9ms preprocess, 134.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 224x320 (no detections), 164.4ms
# Speed: 4.7ms preprocess, 164.4ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x288 1 Speed_Limit_20, 199.2ms
# Speed: 2.2ms preprocess, 199.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 192x320 (no detections), 140.5ms
# Speed: 10.5ms preprocess, 140.5ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 320x256 (no detections), 171.0ms
# Speed: 2.2ms preprocess, 171.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 160x320 (no detections), 142.7ms
# Speed: 2.0ms preprocess, 142.7ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 224x320 (no detections), 239.8ms
# Speed: 10.2ms preprocess, 239.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x288 1 Speed_Limit_20, 191.4ms
# Speed: 6.0ms preprocess, 191.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 256x320 (no detections), 190.2ms
# Speed: 3.3ms preprocess, 190.2ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 183.6ms
# Speed: 1.7ms preprocess, 183.6ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x96 (no detections), 104.4ms
# Speed: 1.2ms preprocess, 104.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 160x320 (no detections), 128.4ms
# Speed: 6.7ms preprocess, 128.4ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 171.5ms
# Speed: 1.8ms preprocess, 171.5ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x288 1 Speed_Limit_20, 187.3ms
# Speed: 2.0ms preprocess, 187.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 160x320 (no detections), 129.7ms
# Speed: 1.8ms preprocess, 129.7ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 320x256 (no detections), 180.4ms
# Speed: 2.0ms preprocess, 180.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 224x320 (no detections), 153.4ms
# Speed: 6.1ms preprocess, 153.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 128x320 (no detections), 169.6ms
# Speed: 1.1ms preprocess, 169.6ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 320x288 1 Speed_Limit_20, 180.7ms
# Speed: 10.2ms preprocess, 180.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 256x320 (no detections), 167.0ms
# Speed: 7.4ms preprocess, 167.0ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 192x320 (no detections), 151.6ms
# Speed: 2.1ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 160x320 (no detections), 130.8ms
# Speed: 1.6ms preprocess, 130.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 320x256 (no detections), 191.8ms
# Speed: 2.1ms preprocess, 191.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 128x320 (no detections), 123.2ms
# Speed: 10.9ms preprocess, 123.2ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 256x320 (no detections), 301.7ms
# Speed: 5.0ms preprocess, 301.7ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 200.6ms
# Speed: 2.8ms preprocess, 200.6ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 192x320 (no detections), 150.3ms
# Speed: 2.2ms preprocess, 150.3ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 256x320 (no detections), 190.3ms
# Speed: 1.7ms preprocess, 190.3ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x256 (no detections), 188.5ms
# Speed: 1.7ms preprocess, 188.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x320 (no detections), 238.3ms
# Speed: 7.3ms preprocess, 238.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 256x320 (no detections), 171.0ms
# Speed: 1.4ms preprocess, 171.0ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 128x320 (no detections), 118.9ms
# Speed: 7.2ms preprocess, 118.9ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 192x320 (no detections), 140.3ms
# Speed: 1.2ms preprocess, 140.3ms inference, 0.7ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 (no detections), 137.6ms
# Speed: 9.1ms preprocess, 137.6ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 256x320 (no detections), 177.9ms
# Speed: 1.7ms preprocess, 177.9ms inference, 4.9ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 170.9ms
# Speed: 1.5ms preprocess, 170.9ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 288x320 (no detections), 181.6ms
# Speed: 10.9ms preprocess, 181.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 224x320 (no detections), 166.1ms
# Speed: 1.7ms preprocess, 166.1ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 256x320 (no detections), 173.2ms
# Speed: 7.1ms preprocess, 173.2ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 160x320 (no detections), 134.8ms
# Speed: 1.4ms preprocess, 134.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 192x320 (no detections), 146.9ms
# Speed: 2.7ms preprocess, 146.9ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 160x320 (no detections), 135.4ms
# Speed: 11.6ms preprocess, 135.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 270.9ms
# Speed: 3.3ms preprocess, 270.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 176.2ms
# Speed: 3.3ms preprocess, 176.2ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 288x320 (no detections), 216.7ms
# Speed: 6.0ms preprocess, 216.7ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 320x128 (no detections), 177.3ms
# Speed: 1.4ms preprocess, 177.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 128)
#
# 0: 320x96 (no detections), 158.7ms
# Speed: 4.1ms preprocess, 158.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 320x224 (no detections), 167.9ms
# Speed: 1.5ms preprocess, 167.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x64 (no detections), 84.7ms
# Speed: 1.5ms preprocess, 84.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x320 (no detections), 203.2ms
# Speed: 2.6ms preprocess, 203.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 256x320 (no detections), 173.9ms
# Speed: 2.4ms preprocess, 173.9ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 224x320 (no detections), 169.7ms
# Speed: 1.8ms preprocess, 169.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 256x320 (no detections), 172.6ms
# Speed: 1.7ms preprocess, 172.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 224x320 (no detections), 191.1ms
# Speed: 1.8ms preprocess, 191.1ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 288x320 (no detections), 195.1ms
# Speed: 1.7ms preprocess, 195.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 320x128 (no detections), 124.8ms
# Speed: 1.5ms preprocess, 124.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 128)
#
# 0: 224x320 (no detections), 167.9ms
# Speed: 1.7ms preprocess, 167.9ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x224 (no detections), 162.4ms
# Speed: 5.0ms preprocess, 162.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x256 (no detections), 190.8ms
# Speed: 2.0ms preprocess, 190.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 256x320 (no detections), 194.6ms
# Speed: 1.5ms preprocess, 194.6ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x160 (no detections), 138.8ms
# Speed: 1.4ms preprocess, 138.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 160)
#
# 0: 320x192 (no detections), 167.0ms
# Speed: 1.7ms preprocess, 167.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 192)
#
# 0: 320x224 (no detections), 168.9ms
# Speed: 1.5ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 166.0ms
# Speed: 1.4ms preprocess, 166.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 193.2ms
# Speed: 2.1ms preprocess, 193.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x192 (no detections), 230.6ms
# Speed: 8.8ms preprocess, 230.6ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 192)
#
# 0: 320x224 (no detections), 177.3ms
# Speed: 6.2ms preprocess, 177.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 195.9ms
# Speed: 1.5ms preprocess, 195.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 159.0ms
# Speed: 1.5ms preprocess, 159.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x160 (no detections), 133.5ms
# Speed: 1.4ms preprocess, 133.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 160)
#
# 0: 320x128 (no detections), 128.7ms
# Speed: 1.0ms preprocess, 128.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 128)
#
# 0: 320x192 (no detections), 160.7ms
# Speed: 1.6ms preprocess, 160.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 192)
#
# 0: 320x224 (no detections), 164.4ms
# Speed: 1.3ms preprocess, 164.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x160 (no detections), 136.8ms
# Speed: 1.6ms preprocess, 136.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 160)
#
# 0: 320x224 (no detections), 164.1ms
# Speed: 1.4ms preprocess, 164.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 192x320 (no detections), 156.7ms
# Speed: 1.5ms preprocess, 156.7ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 320x256 (no detections), 187.7ms
# Speed: 2.2ms preprocess, 187.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x320 (no detections), 208.8ms
# Speed: 2.9ms preprocess, 208.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x64 (no detections), 72.4ms
# Speed: 6.6ms preprocess, 72.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x224 (no detections), 171.6ms
# Speed: 9.1ms preprocess, 171.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 163.7ms
# Speed: 1.5ms preprocess, 163.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 159.6ms
# Speed: 1.6ms preprocess, 159.6ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 224x320 (no detections), 173.4ms
# Speed: 12.8ms preprocess, 173.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x224 (no detections), 207.6ms
# Speed: 4.3ms preprocess, 207.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 192x320 (no detections), 156.8ms
# Speed: 14.5ms preprocess, 156.8ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 320x128 (no detections), 127.5ms
# Speed: 1.3ms preprocess, 127.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 128)
#
# 0: 320x96 (no detections), 106.7ms
# Speed: 2.8ms preprocess, 106.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 320x224 (no detections), 174.0ms
# Speed: 1.8ms preprocess, 174.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 199.3ms
# Speed: 2.6ms preprocess, 199.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 (no detections), 266.7ms
# Speed: 1.3ms preprocess, 266.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x224 1 Yield, 169.6ms
# Speed: 4.7ms preprocess, 169.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x128 (no detections), 119.9ms
# Speed: 1.3ms preprocess, 119.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 128)
#
# 0: 320x224 (no detections), 162.7ms
# Speed: 1.5ms preprocess, 162.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x128 (no detections), 120.3ms
# Speed: 1.4ms preprocess, 120.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 128)
#
# 0: 320x64 (no detections), 80.9ms
# Speed: 1.2ms preprocess, 80.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x224 (no detections), 167.8ms
# Speed: 2.6ms preprocess, 167.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 224x320 (no detections), 161.7ms
# Speed: 1.8ms preprocess, 161.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x64 (no detections), 73.9ms
# Speed: 2.4ms preprocess, 73.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x224 (no detections), 184.4ms
# Speed: 1.9ms preprocess, 184.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 224x320 (no detections), 204.4ms
# Speed: 11.2ms preprocess, 204.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x96 (no detections), 109.9ms
# Speed: 1.0ms preprocess, 109.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 320x224 (no detections), 191.4ms
# Speed: 7.4ms preprocess, 191.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 128x320 (no detections), 112.5ms
# Speed: 1.4ms preprocess, 112.5ms inference, 1.8ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 256x320 (no detections), 172.9ms
# Speed: 1.7ms preprocess, 172.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x96 (no detections), 146.2ms
# Speed: 1.5ms preprocess, 146.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 128x320 (no detections), 163.4ms
# Speed: 1.7ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 256x320 (no detections), 250.1ms
# Speed: 15.0ms preprocess, 250.1ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 224x320 (no detections), 211.4ms
# Speed: 3.6ms preprocess, 211.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 96x320 (no detections), 103.0ms
# Speed: 12.5ms preprocess, 103.0ms inference, 0.4ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 256x320 (no detections), 184.0ms
# Speed: 2.2ms preprocess, 184.0ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 160x320 (no detections), 133.2ms
# Speed: 1.7ms preprocess, 133.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 160x320 (no detections), 145.2ms
# Speed: 2.2ms preprocess, 145.2ms inference, 0.9ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 174.2ms
# Speed: 7.2ms preprocess, 174.2ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x256 (no detections), 170.6ms
# Speed: 2.6ms preprocess, 170.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 320x160 (no detections), 140.8ms
# Speed: 1.5ms preprocess, 140.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 160)
#
# 0: 256x320 (no detections), 172.0ms
# Speed: 8.4ms preprocess, 172.0ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 166.7ms
# Speed: 1.5ms preprocess, 166.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 160x320 (no detections), 136.4ms
# Speed: 7.7ms preprocess, 136.4ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 160x320 (no detections), 133.2ms
# Speed: 2.4ms preprocess, 133.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 174.8ms
# Speed: 1.9ms preprocess, 174.8ms inference, 3.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x288 (no detections), 202.6ms
# Speed: 4.8ms preprocess, 202.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 64x320 (no detections), 207.2ms
# Speed: 1.3ms preprocess, 207.2ms inference, 0.5ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 64x320 (no detections), 81.1ms
# Speed: 11.9ms preprocess, 81.1ms inference, 0.5ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 320x320 1 Stop, 211.5ms
# Speed: 5.8ms preprocess, 211.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x256 (no detections), 173.6ms
# Speed: 1.7ms preprocess, 173.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 64x320 (no detections), 66.6ms
# Speed: 1.0ms preprocess, 66.6ms inference, 0.5ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 64x320 (no detections), 79.4ms
# Speed: 1.2ms preprocess, 79.4ms inference, 0.8ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 160x320 (no detections), 180.4ms
# Speed: 1.6ms preprocess, 180.4ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 320x320 1 Stop, 266.5ms
# Speed: 2.5ms preprocess, 266.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 192x320 (no detections), 146.4ms
# Speed: 1.3ms preprocess, 146.4ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 160x320 (no detections), 138.0ms
# Speed: 3.2ms preprocess, 138.0ms inference, 1.7ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 196.0ms
# Speed: 1.9ms preprocess, 196.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 262.2ms
# Speed: 7.4ms preprocess, 262.2ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x256 (no detections), 257.9ms
# Speed: 2.7ms preprocess, 257.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 64x320 (no detections), 68.1ms
# Speed: 1.3ms preprocess, 68.1ms inference, 0.4ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 64x320 (no detections), 59.7ms
# Speed: 11.4ms preprocess, 59.7ms inference, 0.4ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 320x320 1 Stop, 208.6ms
# Speed: 1.9ms preprocess, 208.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 192x320 (no detections), 157.8ms
# Speed: 2.9ms preprocess, 157.8ms inference, 0.4ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 320x256 (no detections), 177.3ms
# Speed: 1.9ms preprocess, 177.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 96x320 (no detections), 90.6ms
# Speed: 7.5ms preprocess, 90.6ms inference, 0.4ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 64x320 (no detections), 69.5ms
# Speed: 1.3ms preprocess, 69.5ms inference, 0.5ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 96x320 (no detections), 269.4ms
# Speed: 1.3ms preprocess, 269.4ms inference, 0.5ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 96x320 (no detections), 96.5ms
# Speed: 1.7ms preprocess, 96.5ms inference, 1.2ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 320x320 1 Stop, 235.3ms
# Speed: 2.1ms preprocess, 235.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 160x320 (no detections), 140.5ms
# Speed: 1.2ms preprocess, 140.5ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 224x320 (no detections), 159.8ms
# Speed: 1.6ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 320x320 (no detections), 201.1ms
# Speed: 4.1ms preprocess, 201.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 256x320 (no detections), 173.6ms
# Speed: 2.2ms preprocess, 173.6ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 224x320 (no detections), 159.6ms
# Speed: 9.3ms preprocess, 159.6ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 96x320 (no detections), 118.4ms
# Speed: 1.5ms preprocess, 118.4ms inference, 0.5ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 64x320 (no detections), 78.4ms
# Speed: 1.3ms preprocess, 78.4ms inference, 2.5ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 96x320 (no detections), 107.2ms
# Speed: 1.4ms preprocess, 107.2ms inference, 0.5ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 96x320 (no detections), 93.9ms
# Speed: 1.8ms preprocess, 93.9ms inference, 5.0ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 320x320 1 Stop, 199.4ms
# Speed: 8.0ms preprocess, 199.4ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 160x320 (no detections), 130.6ms
# Speed: 8.1ms preprocess, 130.6ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 128x320 (no detections), 123.5ms
# Speed: 1.2ms preprocess, 123.5ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 256x320 (no detections), 187.5ms
# Speed: 1.9ms preprocess, 187.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 172.5ms
# Speed: 1.4ms preprocess, 172.5ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 224x320 (no detections), 151.4ms
# Speed: 1.6ms preprocess, 151.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 96x320 (no detections), 95.7ms
# Speed: 1.4ms preprocess, 95.7ms inference, 0.5ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 96x320 (no detections), 118.5ms
# Speed: 1.3ms preprocess, 118.5ms inference, 0.6ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 64x320 (no detections), 110.0ms
# Speed: 1.2ms preprocess, 110.0ms inference, 0.7ms postprocess per image at shape (1, 3, 64, 320)
#
# 0: 256x320 (no detections), 298.8ms
# Speed: 7.0ms preprocess, 298.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x320 1 Stop, 219.0ms
# Speed: 2.4ms preprocess, 219.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x96 (no detections), 105.3ms
# Speed: 1.8ms preprocess, 105.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 192x320 (no detections), 155.9ms
# Speed: 4.5ms preprocess, 155.9ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 320x288 (no detections), 191.6ms
# Speed: 2.2ms preprocess, 191.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 288)
#
# 0: 256x320 (no detections), 180.0ms
# Speed: 1.4ms preprocess, 180.0ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 189.1ms
# Speed: 1.3ms preprocess, 189.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 224x320 (no detections), 155.9ms
# Speed: 1.5ms preprocess, 155.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 96x320 (no detections), 113.9ms
# Speed: 1.0ms preprocess, 113.9ms inference, 0.6ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 320x320 1 Stop, 200.8ms
# Speed: 3.2ms preprocess, 200.8ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x256 (no detections), 175.6ms
# Speed: 10.9ms preprocess, 175.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 128x320 (no detections), 116.0ms
# Speed: 2.6ms preprocess, 116.0ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 320x320 1 Stop, 204.2ms
# Speed: 16.3ms preprocess, 204.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x256 (no detections), 183.9ms
# Speed: 1.7ms preprocess, 183.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 192x320 (no detections), 152.9ms
# Speed: 1.3ms preprocess, 152.9ms inference, 0.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 256x320 (no detections), 170.3ms
# Speed: 2.0ms preprocess, 170.3ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 160x320 (no detections), 134.9ms
# Speed: 3.1ms preprocess, 134.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 192x320 (no detections), 152.2ms
# Speed: 1.8ms preprocess, 152.2ms inference, 0.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 160x320 (no detections), 127.9ms
# Speed: 1.4ms preprocess, 127.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 160x320 (no detections), 134.9ms
# Speed: 2.5ms preprocess, 134.9ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 320)
#
# 0: 256x320 (no detections), 169.7ms
# Speed: 2.0ms preprocess, 169.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 256x320 (no detections), 256.8ms
# Speed: 3.2ms preprocess, 256.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 320x256 (no detections), 207.7ms
# Speed: 4.2ms preprocess, 207.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 256)
#
# 0: 256x320 (no detections), 159.7ms
# Speed: 4.5ms preprocess, 159.7ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 320)
#
# 0: 288x320 (no detections), 211.1ms
# Speed: 2.9ms preprocess, 211.1ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 320)
#
# 0: 128x320 (no detections), 118.2ms
# Speed: 2.5ms preprocess, 118.2ms inference, 0.8ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 320x64 (no detections), 90.5ms
# Speed: 2.0ms preprocess, 90.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x64 (no detections), 74.2ms
# Speed: 1.2ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x192 (no detections), 170.7ms
# Speed: 2.0ms preprocess, 170.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 192)
#
# 0: 320x320 (no detections), 227.7ms
# Speed: 1.8ms preprocess, 227.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x96 (no detections), 112.5ms
# Speed: 1.6ms preprocess, 112.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 320x224 (no detections), 170.8ms
# Speed: 2.1ms preprocess, 170.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x64 (no detections), 71.0ms
# Speed: 1.4ms preprocess, 71.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x224 (no detections), 164.0ms
# Speed: 3.0ms preprocess, 164.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x320 (no detections), 206.4ms
# Speed: 2.4ms preprocess, 206.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x96 (no detections), 95.5ms
# Speed: 7.9ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 96)
#
# 0: 320x224 (no detections), 157.9ms
# Speed: 2.3ms preprocess, 157.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x320 (no detections), 212.6ms
# Speed: 1.8ms preprocess, 212.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 195.9ms
# Speed: 2.0ms preprocess, 195.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x64 (no detections), 76.6ms
# Speed: 1.3ms preprocess, 76.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x224 (no detections), 168.9ms
# Speed: 2.0ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 96x320 (no detections), 98.9ms
# Speed: 1.9ms preprocess, 98.9ms inference, 0.5ms postprocess per image at shape (1, 3, 96, 320)
#
# 0: 320x320 (no detections), 201.9ms
# Speed: 2.0ms preprocess, 201.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 214.5ms
# Speed: 2.6ms preprocess, 214.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x224 (no detections), 232.3ms
# Speed: 3.3ms preprocess, 232.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 320x320 (no detections), 285.6ms
# Speed: 2.9ms preprocess, 285.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x320 (no detections), 225.0ms
# Speed: 1.8ms preprocess, 225.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 320)
#
# 0: 320x64 (no detections), 82.0ms
# Speed: 1.4ms preprocess, 82.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 64)
#
# 0: 320x224 (no detections), 167.8ms
# Speed: 2.2ms preprocess, 167.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 224)
#
# 0: 128x320 (no detections), 115.1ms
# Speed: 2.5ms preprocess, 115.1ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 320)
#
# 0: 320x128 (no detections), 166.4ms
# Speed: 1.2ms preprocess, 166.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 128)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Multi Threading

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import threading
import time
import queue

# Load YOLO model
model = YOLO("./Model/working/gtsrb_training/weights/best.pt")  # Replace with your trained model path

# Queue to hold frames for ROI extraction and YOLO prediction
roi_queue = queue.Queue(maxsize=10)  # Queue for storing extracted ROIs
prediction_queue = queue.Queue(maxsize=10)  # Queue for storing YOLO predictions

# Lock to prevent race conditions while accessing shared resources
frame_lock = threading.Lock()
frame = None  # Shared variable to hold the current frame

def detect_shapes_and_predict(frame):
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Edge detection
    edges = cv2.Canny(blurred, 50, 150)

    # Find contours with hierarchy
    contours, hierarchy = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    for i, contour in enumerate(contours):
        # Filter only outermost contours
        if hierarchy[0][i][3] != -1:  # Check if contour has a parent
            continue

        # Ignore small contours
        area = cv2.contourArea(contour)
        if area < 500:  # Adjust this threshold to suit your application
            continue

        # Approximate the contour to a polygon
        epsilon = 0.04 * cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, epsilon, True)

        # Identify shapes
        x, y, w, h = cv2.boundingRect(approx)
        shape = None
        if len(approx) == 3:
            shape = "Triangle"
        elif len(approx) == 4:
            shape = "Rectangle"
        elif len(approx) > 4:
            (cx, cy), radius = cv2.minEnclosingCircle(contour)
            if radius > 10:  # Filter small circles
                shape = "Circle"

        # If a shape is identified, crop the ROI
        if shape:
            roi = frame[y:y+h, x:x+w]  # Crop the region of interest
            if roi.size > 0:  # Ensure ROI is not empty
                roi_queue.put((roi, (x, y, w, h)))  # Add the ROI and its bounding box for later processing

    return frame

def yolo_prediction_thread():
    while True:
        # Get ROI from the queue for YOLO prediction
        if not roi_queue.empty():
            roi, bbox = roi_queue.get()

            if roi.size > 0:
                # Perform YOLO prediction
                results = model.predict(roi, conf=0.8, imgsz=256)  # Reduce `imgsz` to speed up processing

                # Process YOLO predictions
                for result in results[0].boxes:
                    conf = result.conf.item()  # Confidence of the prediction
                    cls = result.cls.item()  # Class index
                    label = results[0].names[int(cls)]  # Class name

                    if conf > 0.8:  # Apply confidence threshold
                        prediction_queue.put((bbox, label, conf))  # Store prediction result and bounding box in the queue


def video_capture_thread():
    global frame
    cap = cv2.VideoCapture(0)  # 0 for default camera

    while cap.isOpened():
        ret, frame_data = cap.read()
        if not ret:
            break

        # Acquire lock to safely update shared frame
        with frame_lock:
            frame = frame_data

        # Process the frame for shape and ROI extraction
        detect_shapes_and_predict(frame)

    cap.release()

def main():
    # Start the video capture thread
    capture_thread = threading.Thread(target=video_capture_thread, daemon=True)
    capture_thread.start()

    # Start the YOLO prediction thread
    yolo_thread = threading.Thread(target=yolo_prediction_thread, daemon=True)
    yolo_thread.start()

    while True:
        with frame_lock:
            if frame is None:
                continue

            if not prediction_queue.empty():
                bbox, label, conf = prediction_queue.get()

                # Display the output with YOLO label and confidence on the original frame
                x, y, w, h = bbox
                cv2.putText(frame, f"{label}: {conf:.2f}", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
                cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

            # Display the updated frame with all predictions
            cv2.imshow("Real-Time Shape and YOLO Detection", frame)

            # Exit on 'q' key
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# 0: 256x96 (no detections), 242.6ms
# Speed: 10.2ms preprocess, 242.6ms inference, 13.6ms postprocess per image at shape (1, 3, 256, 96)
#
# 0: 256x224 (no detections), 286.0ms
# Speed: 3.4ms preprocess, 286.0ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 224)
#
# 0: 256x128 (no detections), 135.1ms
# Speed: 1.1ms preprocess, 135.1ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x160 (no detections), 150.9ms
# Speed: 1.8ms preprocess, 150.9ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 160)
#
# 0: 256x224 (no detections), 183.5ms
# Speed: 2.6ms preprocess, 183.5ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 224)
#
# 0: 256x224 (no detections), 304.9ms
# Speed: 1.8ms preprocess, 304.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 224)
#
# 0: 256x96 (no detections), 109.4ms
# Speed: 1.7ms preprocess, 109.4ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 96)
#
# 0: 128x256 (no detections), 241.2ms
# Speed: 2.6ms preprocess, 241.2ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 (no detections), 128.9ms
# Speed: 1.2ms preprocess, 128.9ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 (no detections), 150.3ms
# Speed: 15.7ms preprocess, 150.3ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x128 (no detections), 148.9ms
# Speed: 2.0ms preprocess, 148.9ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x256 1 Speed_Limit_20, 195.7ms
# Speed: 12.7ms preprocess, 195.7ms inference, 7.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 224x256 1 Speed_Limit_50, 266.6ms
# Speed: 1.5ms preprocess, 266.6ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 256)
#
# 0: 160x256 (no detections), 162.7ms
# Speed: 4.2ms preprocess, 162.7ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 128x256 (no detections), 130.5ms
# Speed: 5.4ms preprocess, 130.5ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 230.9ms
# Speed: 2.0ms preprocess, 230.9ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 224x256 (no detections), 176.7ms
# Speed: 10.7ms preprocess, 176.7ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 256)
#
# 0: 128x256 (no detections), 158.1ms
# Speed: 2.6ms preprocess, 158.1ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 (no detections), 177.1ms
# Speed: 1.9ms preprocess, 177.1ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 64x256 (no detections), 87.3ms
# Speed: 2.4ms preprocess, 87.3ms inference, 0.4ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 96x256 (no detections), 132.8ms
# Speed: 2.3ms preprocess, 132.8ms inference, 0.4ms postprocess per image at shape (1, 3, 96, 256)
#
# 0: 128x256 (no detections), 129.2ms
# Speed: 1.5ms preprocess, 129.2ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 189.6ms
# Speed: 8.8ms preprocess, 189.6ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 128x256 (no detections), 259.0ms
# Speed: 1.2ms preprocess, 259.0ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 (no detections), 114.7ms
# Speed: 5.1ms preprocess, 114.7ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 64x256 (no detections), 81.8ms
# Speed: 1.6ms preprocess, 81.8ms inference, 0.6ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 64x256 (no detections), 76.5ms
# Speed: 11.3ms preprocess, 76.5ms inference, 0.6ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 128x256 (no detections), 126.2ms
# Speed: 2.1ms preprocess, 126.2ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 175.9ms
# Speed: 17.6ms preprocess, 175.9ms inference, 3.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 128x256 (no detections), 119.7ms
# Speed: 1.3ms preprocess, 119.7ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 128x256 1 Construction, 107.1ms
# Speed: 13.7ms preprocess, 107.1ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 64x256 (no detections), 70.2ms
# Speed: 12.7ms preprocess, 70.2ms inference, 0.7ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 128x256 (no detections), 125.5ms
# Speed: 2.4ms preprocess, 125.5ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 198.2ms
# Speed: 11.9ms preprocess, 198.2ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 160x256 (no detections), 217.3ms
# Speed: 17.6ms preprocess, 217.3ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 128x256 (no detections), 257.4ms
# Speed: 2.3ms preprocess, 257.4ms inference, 0.4ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 64x256 (no detections), 71.0ms
# Speed: 10.2ms preprocess, 71.0ms inference, 0.5ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 96x256 (no detections), 98.5ms
# Speed: 1.8ms preprocess, 98.5ms inference, 0.7ms postprocess per image at shape (1, 3, 96, 256)
#
# 0: 128x256 (no detections), 127.5ms
# Speed: 1.0ms preprocess, 127.5ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 189.9ms
# Speed: 12.2ms preprocess, 189.9ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x192 (no detections), 186.3ms
# Speed: 11.3ms preprocess, 186.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 192)
#
# 0: 256x160 (no detections), 146.9ms
# Speed: 2.4ms preprocess, 146.9ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 160)
#
# 0: 160x256 (no detections), 140.8ms
# Speed: 1.7ms preprocess, 140.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 136.5ms
# Speed: 2.6ms preprocess, 136.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 128x256 (no detections), 129.3ms
# Speed: 13.4ms preprocess, 129.3ms inference, 0.8ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 192.3ms
# Speed: 15.0ms preprocess, 192.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 160x256 (no detections), 132.7ms
# Speed: 21.6ms preprocess, 132.7ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 64x256 (no detections), 83.8ms
# Speed: 1.3ms preprocess, 83.8ms inference, 0.7ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 64x256 (no detections), 66.8ms
# Speed: 7.8ms preprocess, 66.8ms inference, 0.6ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 128x256 (no detections), 136.9ms
# Speed: 2.5ms preprocess, 136.9ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 261.4ms
# Speed: 3.2ms preprocess, 261.4ms inference, 4.0ms postprocess per image at shape (1, 3, 256, 256)
# 0: 128x256 (no detections), 188.7ms
# Speed: 1.9ms preprocess, 188.7ms inference, 1.0ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 160x256 (no detections), 369.8ms
# Speed: 5.4ms preprocess, 369.8ms inference, 0.4ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 96x256 (no detections), 170.0ms
# Speed: 3.1ms preprocess, 170.0ms inference, 1.0ms postprocess per image at shape (1, 3, 96, 256)
#
# 0: 64x256 (no detections), 176.2ms
# Speed: 2.5ms preprocess, 176.2ms inference, 0.7ms postprocess per image at shape (1, 3, 64, 256)
#
# 0: 128x256 (no detections), 190.6ms
# Speed: 1.8ms preprocess, 190.6ms inference, 0.6ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x256 1 Speed_Limit_20, 221.3ms
# Speed: 25.8ms preprocess, 221.3ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 346.7ms
# Speed: 1.4ms preprocess, 346.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 1 Speed_Limit_20, 436.5ms
# Speed: 20.1ms preprocess, 436.5ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 96x256 (no detections), 260.5ms
# Speed: 45.7ms preprocess, 260.5ms inference, 0.6ms postprocess per image at shape (1, 3, 96, 256)
#
# 0: 256x128 (no detections), 146.9ms
# Speed: 79.1ms preprocess, 146.9ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x256 (no detections), 333.5ms
# Speed: 32.8ms preprocess, 333.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 146.4ms
# Speed: 41.5ms preprocess, 146.4ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 232.6ms
# Speed: 2.3ms preprocess, 232.6ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 128x256 (no detections), 118.9ms
# Speed: 46.1ms preprocess, 118.9ms inference, 0.7ms postprocess per image at shape (1, 3, 128, 256)
#
# 0: 256x64 (no detections), 137.6ms
# Speed: 6.7ms preprocess, 137.6ms inference, 1.6ms postprocess per image at shape (1, 3, 256, 64)
#
# 0: 256x192 (no detections), 233.6ms
# Speed: 104.3ms preprocess, 233.6ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 192)
#
# 0: 256x96 (no detections), 217.7ms
# Speed: 25.7ms preprocess, 217.7ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 96)
#
# 0: 224x256 (no detections), 408.5ms
# Speed: 30.6ms preprocess, 408.5ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 256)
#
# 0: 256x128 (no detections), 514.1ms
# Speed: 7.0ms preprocess, 514.1ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x128 (no detections), 337.3ms
# Speed: 39.3ms preprocess, 337.3ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x128 (no detections), 525.7ms
# Speed: 29.0ms preprocess, 525.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x128 (no detections), 238.5ms
# Speed: 58.5ms preprocess, 238.5ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x96 (no detections), 196.1ms
# Speed: 3.0ms preprocess, 196.1ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 96)
#
# 0: 192x256 (no detections), 237.0ms
# Speed: 33.3ms preprocess, 237.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 256)
#
# 0: 256x96 (no detections), 349.0ms
# Speed: 2.3ms preprocess, 349.0ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 96)
#
# 0: 256x160 (no detections), 129.3ms
# Speed: 36.2ms preprocess, 129.3ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 160)
#
# 0: 256x128 (no detections), 158.4ms
# Speed: 1.0ms preprocess, 158.4ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 128)
#
# 0: 256x256 (no detections), 315.7ms
# Speed: 21.4ms preprocess, 315.7ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 256)
#
# 0: 256x256 (no detections), 260.3ms
# Speed: 62.7ms preprocess, 260.3ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
